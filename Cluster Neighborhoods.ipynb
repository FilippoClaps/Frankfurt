# %% [markdown]
# # Clustering Frankfurt's Neighborhoods
#
# Import libraries

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors

import requests # Return HTML pages as string
import json # Extract data from JSON files
import folium # Map plotting library
from geopy.geocoders import Nominatim # Convert an address into latitude and longitude values
from bs4 import BeautifulSoup # Extract data from HTML page
import warnings # Suppres Pandas Warnings

# %% [markdown]
# import the neighborhoods csv file and preprocess the dataset

# %%
# Suppress pandas warning on .loc
warnings.filterwarnings('ignore')

# Read the csv file containing the names of districts in the Frankfurt Municipality
neighborhoods = pd.read_csv('ffm_neighborhoods.csv', index_col=False)

neighborhoods['Latitude'] = np.nan
neighborhoods['Longitude'] = np.nan

geolocator = Nominatim(user_agent='to_explorer')

for neighborhood in neighborhoods['Neighborhood']:
    location = geolocator.geocode(neighborhood + ', Frankfurt am Main')
    if location:
        neighborhoods.loc[neighborhoods['Neighborhood']==neighborhood, 'Latitude'] = location.latitude
        neighborhoods.loc[neighborhoods['Neighborhood']==neighborhood, 'Longitude'] = location.longitude
        
neighborhoods.head()
# Out:
#       Neighborhood   Latitude  Longitude
# 0           Gallus  50.103840   8.643101
# 1   Gutleutviertel  50.099203   8.663941
# 2  Bahnhofsviertel  50.099203   8.663941
# 3         Altstadt  50.108052   8.682161
# 4       Innenstadt  50.108052   8.682161

# %% [markdown]
# Clean the dataframe

# %%
neighborhoods.dropna(inplace=True)
neighborhoods.drop_duplicates(subset=['Latitude', 'Longitude'], inplace=True)
neighborhoods.reset_index(drop=True, inplace=True)
neighborhoods.shape
# Out:
# (40, 3)

# %% [markdown]
# Visualize districts on the map

# %%
geolocator = Nominatim(user_agent='to_explorer')
location = geolocator.geocode('Frankfurt am Main')


map_ffm = folium.Map(location=[location.latitude, location.longitude], zoom_start=12)

for latitude, longitude, district in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Neighborhood']):
    label = folium.Popup(str(district))
    folium.CircleMarker([latitude, longitude], radius=5, popup=label, fill=True, fill_opacity=0.7).add_to(map_ffm)
       
map_ffm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <br>
# Defining a function that will exctract venue data with the Fourquare API
# <br>
# <br>

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=1500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, CLIENT_SECRET, VERSION, lat, lng, radius, LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(name, lat, lng, v['venue']['name'], v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 'Neighborhood Latitude', 'Neighborhood Longitude', 'Venue', 
                  'Venue Latitude', 'Venue Longitude', 'Venue Category']
    print('Venues extracted!')
    return(nearby_venues)

# %%
CLIENT_ID = '#################################' # your Foursquare ID
CLIENT_SECRET = '#################################' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 200 # limit of number of venues returned by Foursquare API

ffm = getNearbyVenues(names=neighborhoods['Neighborhood'], latitudes=neighborhoods['Latitude'], longitudes=neighborhoods['Longitude'])
ffm.head()
# Out:
# Venues extracted!
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0       Gallus               50.10384                8.643101
# 1       Gallus               50.10384                8.643101
# 2       Gallus               50.10384                8.643101
# 3       Gallus               50.10384                8.643101
# 4       Gallus               50.10384                8.643101
#
#                        Venue  Venue Latitude  Venue Longitude  \
# 0              DORMERO Hotel       50.108106         8.644107
# 1                   Basaglia       50.104273         8.647170
# 2  Capri by Fraser Frankfurt       50.108896         8.648790
# 3         Alim's Fischimbiss       50.102392         8.636990
# 4             Melody Karaoke       50.101060         8.634424
#
#        Venue Category
# 0               Hotel
# 1                Café
# 2               Hotel
# 3  Seafood Restaurant
# 4         Karaoke Bar

# %%
# Eliminate duplicate venues
ffm.drop_duplicates(subset='Venue', inplace=True)

print('The number of venues extracted is: ' + str(ffm.shape[0]) + '.')
print('There are {} uniques venue categories.'.format(len(ffm['Venue Category'].unique())))
print('Those venues are located in {} different neighborhoods.'.format(len(ffm['Neighborhood'].unique())))

# Export the results in csv to avoid querying Foursquare too much
#ffm.to_csv('ffm_venues.csv', index=False)
# Out:
# The number of venues extracted is: 1198.
# There are 239 uniques venue categories.
# Those venues are located in 38 different neighborhoods.

# %%
geolocator = Nominatim(user_agent='to_explorer')
location = geolocator.geocode('Frankfurt am Main')

map_ffm = folium.Map(location=[location.latitude, location.longitude], zoom_start=12)

for latitude, longitude, venue in zip(ffm['Venue Latitude'], ffm['Venue Longitude'], ffm['Venue']):
    label = folium.Popup(str(venue))
    folium.CircleMarker([latitude, longitude], radius=4, popup=label, fill=True, fill_opacity=0.7).add_to(map_ffm)
       
map_ffm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ffm.groupby('Neighborhood')['Venue'].count()
# Out:
# Neighborhood
# Altstadt             71
# Bergen-Enkheim        8
# Berkersheim           9
# Bockenheim           82
# Bonames              15
# Dornbusch            17
# Eckenheim            23
# Eschersheim           6
# Fechenheim           16
# Flughafen            92
# Gallus              100
# Ginnheim             18
# Gutleutviertel       77
# Hausen               14
# Heddernheim          14
# Höchst               15
# Kalbach-Riedberg     13
# Nied                 17
# Nieder-Erlenbach      5
# Nieder-Eschbach       5
# Niederrad            58
# Niederursel          16
# Nordend-Ost          55
# Nordend-West         21
# Oberrad              88
# Ostend               46
# Praunheim            29
# Preungesheim          4
# Riederwald           28
# Rödelheim            40
# Schwanheim           27
# Seckbach             26
# Sindlingen            5
# Sossenheim           18
# Unterliederbach      43
# Westend-Nord         46
# Westend-Süd          25
# Zeilsheim             6
# Name: Venue, dtype: int64

# %% [markdown]
# ## Analyze Neighborhoods

# %%
# lets get a one hot encoding of all differen
ffm_onehot = pd.get_dummies(ffm[['Venue Category']], prefix="", prefix_sep="")

# add District column to dataframe
ffm_onehot.insert(0, 'Neighborhood', ffm['Neighborhood'])
ffm_onehot.shape
# Out:
# (1198, 240)

# %% [markdown]
# Next, let's group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

# %%
ffm_grouped = ffm_onehot.groupby('Neighborhood').mean().reset_index()
ffm_grouped.head(10)
# Out:
#      Neighborhood  Accessories Store  African Restaurant  Airport  \
# 0        Altstadt            0.00000                 0.0  0.00000
# 1  Bergen-Enkheim            0.00000                 0.0  0.00000
# 2     Berkersheim            0.00000                 0.0  0.00000
# 3      Bockenheim            0.00000                 0.0  0.00000
# 4         Bonames            0.00000                 0.0  0.00000
# 5       Dornbusch            0.00000                 0.0  0.00000
# 6       Eckenheim            0.00000                 0.0  0.00000
# 7     Eschersheim            0.00000                 0.0  0.00000
# 8      Fechenheim            0.00000                 0.0  0.00000
# 9       Flughafen            0.01087                 0.0  0.01087
#
#    Airport Lounge  Airport Service  Airport Terminal  American Restaurant  \
# 0        0.000000         0.000000           0.00000             0.000000
# 1        0.000000         0.000000           0.00000             0.000000
# 2        0.000000         0.000000           0.00000             0.000000
# 3        0.000000         0.000000           0.00000             0.012195
# 4        0.000000         0.000000           0.00000             0.000000
# 5        0.000000         0.000000           0.00000             0.000000
# 6        0.000000         0.000000           0.00000             0.000000
# 7        0.000000         0.000000           0.00000             0.000000
# 8        0.000000         0.000000           0.00000             0.000000
# 9        0.195652         0.119565           0.01087             0.010870
#
#    Apple Wine Pub  Arcade  ...  Transportation Service  Trattoria/Osteria  \
# 0        0.056338     0.0  ...                 0.00000           0.028169
# 1        0.000000     0.0  ...                 0.00000           0.000000
# 2        0.000000     0.0  ...                 0.00000           0.000000
# 3        0.000000     0.0  ...                 0.00000           0.000000
# 4        0.000000     0.0  ...                 0.00000           0.000000
# 5        0.000000     0.0  ...                 0.00000           0.000000
# 6        0.000000     0.0  ...                 0.00000           0.000000
# 7        0.000000     0.0  ...                 0.00000           0.166667
# 8        0.000000     0.0  ...                 0.00000           0.000000
# 9        0.000000     0.0  ...                 0.01087           0.000000
#
#    Turkish Restaurant  Vegetarian / Vegan Restaurant  Video Game Store  \
# 0             0.00000                       0.000000               0.0
# 1             0.00000                       0.000000               0.0
# 2             0.00000                       0.000000               0.0
# 3             0.02439                       0.000000               0.0
# 4             0.00000                       0.000000               0.0
# 5             0.00000                       0.058824               0.0
# 6             0.00000                       0.000000               0.0
# 7             0.00000                       0.000000               0.0
# 8             0.00000                       0.000000               0.0
# 9             0.00000                       0.000000               0.0
#
#    Vietnamese Restaurant  Water Park  Waterfront  Wine Bar  Wine Shop
# 0               0.014085       0.000         0.0  0.028169        0.0
# 1               0.000000       0.125         0.0  0.000000        0.0
# 2               0.000000       0.000         0.0  0.000000        0.0
# 3               0.012195       0.000         0.0  0.036585        0.0
# 4               0.000000       0.000         0.0  0.000000        0.0
# 5               0.000000       0.000         0.0  0.000000        0.0
# 6               0.000000       0.000         0.0  0.000000        0.0
# 7               0.000000       0.000         0.0  0.000000        0.0
# 8               0.000000       0.000         0.0  0.000000        0.0
# 9               0.000000       0.000         0.0  0.010870        0.0
#
# [10 rows x 240 columns]

# %%
ffm_grouped.shape
# Out:
# (38, 240)

# %%
num_top_venues = 5

for hood in ffm_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = ffm_grouped[ffm_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 3})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Altstadt----
#                venue   freq
# 0               Café  0.099
# 1     Apple Wine Pub  0.056
# 2  German Restaurant  0.056
# 3                Bar  0.042
# 4              Plaza  0.042
#
#
# ----Bergen-Enkheim----
#                 venue   freq
# 0      Ice Cream Shop  0.125
# 1  Italian Restaurant  0.125
# 2             Taverna  0.125
# 3   German Restaurant  0.125
# 4               Trail  0.125
#
#
# ----Berkersheim----
#                 venue   freq
# 0         Supermarket  0.111
# 1            Pharmacy  0.111
# 2   German Restaurant  0.111
# 3  Light Rail Station  0.111
# 4            Bus Stop  0.111
#
#
# ----Bockenheim----
#                 venue   freq
# 0  Italian Restaurant  0.122
# 1                Café  0.122
# 2    Asian Restaurant  0.061
# 3    Botanical Garden  0.049
# 4                 Bar  0.037
#
#
# ----Bonames----
#                 venue   freq
# 0                Café  0.133
# 1        Burger Joint  0.067
# 2  Chinese Restaurant  0.067
# 3         Golf Course  0.067
# 4   Electronics Store  0.067
#
#
# ----Dornbusch----
#                        venue   freq
# 0                       Park  0.176
# 1  Cajun / Creole Restaurant  0.059
# 2          German Restaurant  0.059
# 3                     Bakery  0.059
# 4   Mediterranean Restaurant  0.059
#
#
# ----Eckenheim----
#            venue   freq
# 0  Metro Station  0.130
# 1         Bakery  0.087
# 2   Soccer Field  0.087
# 3   Tram Station  0.087
# 4   Climbing Gym  0.087
#
#
# ----Eschersheim----
#                 venue   freq
# 0       Metro Station  0.333
# 1   Trattoria/Osteria  0.167
# 2    Asian Restaurant  0.167
# 3  Italian Restaurant  0.167
# 4        Dessert Shop  0.167
#
#
# ----Fechenheim----
#               venue   freq
# 0  Greek Restaurant  0.125
# 1             Hotel  0.125
# 2      Climbing Gym  0.062
# 3      Gourmet Shop  0.062
# 4      Tennis Court  0.062
#
#
# ----Flughafen----
#                venue   freq
# 0     Airport Lounge  0.196
# 1    Airport Service  0.120
# 2          Hotel Bar  0.043
# 3  German Restaurant  0.043
# 4               Café  0.043
#
#
# ----Gallus----
#                 venue  freq
# 0               Hotel  0.12
# 1  Italian Restaurant  0.08
# 2          Restaurant  0.05
# 3    Asian Restaurant  0.05
# 4         Pizza Place  0.04
#
#
# ----Ginnheim----
#                  venue   freq
# 0    German Restaurant  0.222
# 1         Soccer Field  0.111
# 2        Metro Station  0.111
# 3    Indian Restaurant  0.056
# 4  Japanese Restaurant  0.056
#
#
# ----Gutleutviertel----
#                 venue   freq
# 0                Café  0.078
# 1               Hotel  0.065
# 2                 Bar  0.052
# 3   Indian Restaurant  0.052
# 4  Seafood Restaurant  0.052
#
#
# ----Hausen----
#                venue   freq
# 0      Metro Station  0.214
# 1   Greek Restaurant  0.143
# 2  German Restaurant  0.071
# 3       Soccer Field  0.071
# 4          Pet Store  0.071
#
#
# ----Heddernheim----
#                venue   freq
# 0      Bowling Alley  0.143
# 1  German Restaurant  0.143
# 2     Ice Cream Shop  0.071
# 3      Grocery Store  0.071
# 4               Pool  0.071
#
#
# ----Höchst----
#                venue   freq
# 0         Restaurant  0.133
# 1     Farmers Market  0.067
# 2       Gourmet Shop  0.067
# 3  Electronics Store  0.067
# 4        Supermarket  0.067
#
#
# ----Kalbach-Riedberg----
#                 venue   freq
# 0  Italian Restaurant  0.231
# 1                Park  0.154
# 2   Indian Restaurant  0.077
# 3      Shop & Service  0.077
# 4     Automotive Shop  0.077
#
#
# ----Nied----
#                      venue   freq
# 0                    Hotel  0.118
# 1        German Restaurant  0.118
# 2  Comfort Food Restaurant  0.059
# 3                   Bakery  0.059
# 4                    Plaza  0.059
#
#
# ----Nieder-Erlenbach----
#                 venue  freq
# 0   German Restaurant   0.2
# 1          Steakhouse   0.2
# 2  Mexican Restaurant   0.2
# 3         Pizza Place   0.2
# 4                Café   0.2
#
#
# ----Nieder-Eschbach----
#                     venue  freq
# 0          Ice Cream Shop   0.2
# 1        Insurance Office   0.2
# 2           Metro Station   0.2
# 3             Supermarket   0.2
# 4  Furniture / Home Store   0.2
#
#
# ----Niederrad----
#                 venue   freq
# 0  Italian Restaurant  0.086
# 1        Tram Station  0.086
# 2               Hotel  0.069
# 3         Supermarket  0.052
# 4              Bakery  0.052
#
#
# ----Niederursel----
#                venue   freq
# 0  German Restaurant  0.188
# 1               Café  0.125
# 2             Market  0.062
# 3      Metro Station  0.062
# 4     Ice Cream Shop  0.062
#
#
# ----Nordend-Ost----
#                  venue   freq
# 0                 Café  0.182
# 1   Italian Restaurant  0.073
# 2  Japanese Restaurant  0.036
# 3   Mexican Restaurant  0.036
# 4           Restaurant  0.036
#
#
# ----Nordend-West----
#                venue   freq
# 0               Café  0.238
# 1                Pub  0.095
# 2               Park  0.095
# 3             Bakery  0.095
# 4  Indian Restaurant  0.048
#
#
# ----Oberrad----
#                 venue   freq
# 0               Hotel  0.125
# 1         Supermarket  0.057
# 2  Italian Restaurant  0.045
# 3   German Restaurant  0.045
# 4        Tram Station  0.034
#
#
# ----Ostend----
#                 venue   freq
# 0                Café  0.087
# 1  Italian Restaurant  0.087
# 2          Waterfront  0.065
# 3           Gastropub  0.065
# 4     Thai Restaurant  0.043
#
#
# ----Praunheim----
#                        venue   freq
# 0                       Park  0.103
# 1         Italian Restaurant  0.103
# 2                        Gym  0.069
# 3             Clothing Store  0.069
# 4  Middle Eastern Restaurant  0.034
#
#
# ----Preungesheim----
#                   venue  freq
# 0           Golf Course  0.25
# 1          Intersection  0.25
# 2           Pizza Place  0.25
# 3          Soccer Field  0.25
# 4  Outdoor Supply Store  0.00
#
#
# ----Riederwald----
#                     venue   freq
# 0     Sporting Goods Shop  0.071
# 1      Italian Restaurant  0.071
# 2            Tram Station  0.071
# 3  Furniture / Home Store  0.071
# 4            Intersection  0.036
#
#
# ----Rödelheim----
#              venue   freq
# 0            Hotel  0.100
# 1             Pool  0.050
# 2       Restaurant  0.050
# 3  Bed & Breakfast  0.025
# 4    Big Box Store  0.025
#
#
# ----Schwanheim----
#                venue   freq
# 0  German Restaurant  0.111
# 1       Tram Station  0.111
# 2               Park  0.074
# 3    Thai Restaurant  0.037
# 4          Pet Store  0.037
#
#
# ----Seckbach----
#                   venue   freq
# 0     German Restaurant  0.115
# 1              Bus Stop  0.077
# 2         Metro Station  0.077
# 3                  Park  0.077
# 4  Gym / Fitness Center  0.077
#
#
# ----Sindlingen----
#               venue  freq
# 0       Pizza Place   0.2
# 1     Boat or Ferry   0.2
# 2             Hotel   0.2
# 3  Greek Restaurant   0.2
# 4            Bridge   0.2
#
#
# ----Sossenheim----
#               venue   freq
# 0            Bakery  0.111
# 1              Lake  0.056
# 2  Greek Restaurant  0.056
# 3               Bar  0.056
# 4   Thai Restaurant  0.056
#
#
# ----Unterliederbach----
#                     venue   freq
# 0          Clothing Store  0.140
# 1          Ice Cream Shop  0.093
# 2  Furniture / Home Store  0.047
# 3      Italian Restaurant  0.047
# 4               Multiplex  0.047
#
#
# ----Westend-Nord----
#                    venue   freq
# 0     Italian Restaurant  0.174
# 1                   Café  0.130
# 2                 Bakery  0.043
# 3  Vietnamese Restaurant  0.043
# 4      Korean Restaurant  0.043
#
#
# ----Westend-Süd----
#                  venue  freq
# 0                 Café  0.16
# 1           Steakhouse  0.12
# 2  Japanese Restaurant  0.08
# 3                 Park  0.08
# 4         Gourmet Shop  0.04
#
#
# ----Zeilsheim----
#                      venue   freq
# 0           Ice Cream Shop  0.167
# 1             Intersection  0.167
# 2            Train Station  0.167
# 3       Light Rail Station  0.167
# 4  State / Provincial Park  0.167

# %% [markdown]
# Let's put that into a pandas dataframe
# First, let's write a function to sort the venues in descending order.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:] # exclude District column
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Now let's create the new dataframe and display the top 10 venues for each neighborhood.

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
district_venues_sorted = pd.DataFrame(columns=columns)
district_venues_sorted['Neighborhood'] = ffm_grouped['Neighborhood']

for ind in np.arange(ffm_grouped.shape[0]):
    district_venues_sorted.iloc[ind, 1:] = return_most_common_venues(ffm_grouped.iloc[ind, :], num_top_venues)

district_venues_sorted.head()
# Out:
#      Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0        Altstadt                  Café        Apple Wine Pub
# 1  Bergen-Enkheim                 Trail               Taverna
# 2     Berkersheim                Bakery         Train Station
# 3      Bockenheim    Italian Restaurant                  Café
# 4         Bonames                  Café    Italian Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0     German Restaurant                 Plaza                   Bar
# 1            Water Park                 Plaza        Ice Cream Shop
# 2                 Hotel          Soccer Field    Light Rail Station
# 3      Asian Restaurant      Botanical Garden                Bakery
# 4         Metro Station         Event Service     Electronics Store
#
#            6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                 Scenic Lookout       Thai Restaurant    Falafel Restaurant
# 1  Paper / Office Supplies Store    Italian Restaurant     German Restaurant
# 2                       Pharmacy              Bus Stop           Supermarket
# 3                       Wine Bar                   Bar    Spanish Restaurant
# 4                   Burger Joint         Garden Center      Doner Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 0     Electronics Store     Italian Restaurant
# 1             Wine Shop             Donut Shop
# 2     German Restaurant         Duty-free Shop
# 3           Pizza Place    Japanese Restaurant
# 4    Athletics & Sports            Golf Course

# %% [markdown]
# ## Cluster Neighborhoods

# %%
num_clusters = 5

X = ffm_grouped.drop('Neighborhood', 1)

kmeans = KMeans(n_clusters=num_clusters, random_state=0).fit(X)

# %% [markdown]
# Create a new dataframe that includes the cluster and the top 10 venues for each neighborhood.

# %%
# add clustering labels
district_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

ffm_merged = neighborhoods

# merge labels and data about venues to district data and latitude plus longitude data to have all in one dataframe
ffm_merged = ffm_merged.join(district_venues_sorted.set_index('Neighborhood'), how='inner', on='Neighborhood')

ffm_merged.head()
# Out:
#      Neighborhood   Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 0          Gallus  50.103840   8.643101               0                 Hotel
# 1  Gutleutviertel  50.099203   8.663941               0                  Café
# 2        Altstadt  50.108052   8.682161               0                  Café
# 3      Bockenheim  50.123311   8.646056               0    Italian Restaurant
# 4     Westend-Süd  50.115245   8.662270               0                  Café
#
#   2nd Most Common Venue 3rd Most Common Venue  4th Most Common Venue  \
# 0    Italian Restaurant            Restaurant       Asian Restaurant
# 1                 Hotel    Seafood Restaurant  Vietnamese Restaurant
# 2        Apple Wine Pub     German Restaurant                  Plaza
# 3                  Café      Asian Restaurant       Botanical Garden
# 4            Steakhouse                  Park    Japanese Restaurant
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0           Pizza Place                  Café     Indian Restaurant
# 1     Indian Restaurant                   Bar            Art Museum
# 2                   Bar        Scenic Lookout       Thai Restaurant
# 3                Bakery              Wine Bar                   Bar
# 4    Italian Restaurant        Breakfast Spot             Bookstore
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0           Coffee Shop           Supermarket    Japanese Restaurant
# 1      Asian Restaurant          Cocktail Bar                 Bakery
# 2    Falafel Restaurant     Electronics Store     Italian Restaurant
# 3    Spanish Restaurant           Pizza Place    Japanese Restaurant
# 4     Food & Drink Shop                Market                 Lounge

# %% [markdown]
# Visualize clusters in a Map

# %%
map_clusters = folium.Map(location=[location.latitude, location.longitude], zoom_start=12)

# set color scheme for the clusters
indian_red = '#CD5C5C'
blue = '#2980B9'
purple = '#5B2C6F'
gold = '#F1C40F'
green = '#239B56'
x = np.arange(num_clusters)
rainbow = [indian_red, blue, purple, gold, green]
# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(ffm_merged['Latitude'], ffm_merged['Longitude'], ffm_merged['Neighborhood'], ffm_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Examine Clusters

# %%
cluster0 = ffm_merged.loc[ffm_merged['Cluster Labels'] == 0, ffm_merged.columns[[0] + list(range(4, ffm_merged.shape[1]))]]
cluster0['1st Most Common Venue'].value_counts()
# Out:
# Café                  7
# Italian Restaurant    3
# Airport Lounge        1
# Clothing Store        1
# Hotel                 1
# Mexican Restaurant    1
# Restaurant            1
# Park                  1
# Name: 1st Most Common Venue, dtype: int64

# %%
cluster1 = ffm_merged.loc[ffm_merged['Cluster Labels'] == 1, ffm_merged.columns[[0] + list(range(4, ffm_merged.shape[1]))]]
cluster1['1st Most Common Venue'].value_counts()
# Out:
# Intersection    1
# Name: 1st Most Common Venue, dtype: int64

# %%
cluster2 = ffm_merged.loc[ffm_merged['Cluster Labels'] == 2, ffm_merged.columns[[0] + list(range(4, ffm_merged.shape[1]))]]
cluster2['1st Most Common Venue'].value_counts()
# Out:
# Furniture / Home Store    1
# Name: 1st Most Common Venue, dtype: int64

# %%
cluster3 = ffm_merged.loc[ffm_merged['Cluster Labels'] == 3, ffm_merged.columns[[0] + list(range(4, ffm_merged.shape[1]))]]
cluster3['1st Most Common Venue'].value_counts()
# Out:
# Hotel                  4
# German Restaurant      3
# Metro Station          3
# Tram Station           2
# Bakery                 2
# Sporting Goods Shop    1
# Park                   1
# Bowling Alley          1
# Trail                  1
# Intersection           1
# Name: 1st Most Common Venue, dtype: int64

# %%
cluster4 = ffm_merged.loc[ffm_merged['Cluster Labels'] == 4, ffm_merged.columns[[0] + list(range(4, ffm_merged.shape[1]))]]
cluster4['1st Most Common Venue'].value_counts()
# Out:
# Hotel    1
# Name: 1st Most Common Venue, dtype: int64
